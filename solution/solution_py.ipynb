# %%
# Jupyter notebook
import pandas as pd
import pandasql as psql
import glob

# %%
clinical_codes = pd.read_csv(r'../exa-data-analyst-assessment/data/clinical_codes.csv')
patient = pd.read_csv(r'../exa-data-analyst-assessment/data/patient.csv')

# %%
# Creates a varaible name for each medication file in folder [medication1, medication2, ... ,medicationx]

# Note that variables 0 to 14 are now mapped to filenames 1, 10, 11, 12, 13, 14, 15, 2, 3, 4, 5, 6, 7, 8, 9 respectively

medication_list = glob.glob(r'../exa-data-analyst-assessment/data/medication/*.csv')
for n, val in enumerate(medication_list):
    globals()["medication%d"%n] = pd.read_csv(val, header=None)

# Creates a variable name for each observation file in folder [observation1, observation2, ..., observationx]

# Note that variables 0 to 11 are now mapped to filenames 1, 10, 11, 12, 2, 3, 4, 5, 6, 7, 8, 9 respectively

observation_list = glob.glob(r'../exa-data-analyst-assessment/data/observation/*.csv')
for n, val in enumerate(observation_list):
    globals()["observation%d"%n] = pd.read_csv(val, header=None)
observation0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\3519892758.py:15: DtypeWarning: Columns (0,1,2,3,4,5,8,12,19,20,22,23,24,25,26,30,31,35,36,37,39,40,41,42,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()["observation%d"%n] = pd.read_csv(val, header=None)
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\3519892758.py:15: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()["observation%d"%n] = pd.read_csv(val, header=None)
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\3519892758.py:15: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()["observation%d"%n] = pd.read_csv(val, header=None)
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\3519892758.py:15: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()["observation%d"%n] = pd.read_csv(val, header=None)
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\3519892758.py:15: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()["observation%d"%n] = pd.read_csv(val, header=None)
#              0                1           2                  3   \
# 0      abnormal     emis_code_id  comparator  confidential_flag
# 1         false        254063019         NaN              false
# 2         false        259803019         NaN              false
# 3         false  215711000006110         NaN              false
# 4         false        253669010         NaN              false
# ...         ...              ...         ...                ...
# 23182     False       1208954011         NaN              False
# 23183     False        254063019         NaN              False
# 23184     False        264567012         NaN              False
# 23185      True       1495289019         NaN              False
# 23186     False        259579011         NaN              False
#
#                               4                                 5   \
# 0      confidential_patient_flag  consultation_source_emis_code_id
# 1                          false                  1672871000006114
# 2                          false                  1672871000006114
# 3                          false                  1672871000006114
# 4                          false                  1672871000006114
# ...                          ...                               ...
# 23182                      False                1672871000006114.0
# 23183                      False                1672871000006114.0
# 23184                      False                1672871000006114.0
# 23185                      False                1672871000006114.0
# 23186                      False                               NaN
#
#                                            6              7   \
# 0      consultation_source_emis_original_term  document_guid
# 1                                Main Surgery            NaN
# 2                                Main Surgery            NaN
# 3                                Main Surgery            NaN
# 4                                Main Surgery            NaN
# ...                                       ...            ...
# 23182                            Main Surgery            NaN
# 23183                            Main Surgery            NaN
# 23184                            Main Surgery            NaN
# 23185                General Practice Surgery            NaN
# 23186                                     NaN            NaN
#
#                        8                    9   ...                      40  \
# 0      dummy_patient_flag       effective_date  ...  sensitive_patient_flag
# 1                   false  1999-08-12 00:00:00  ...                   false
# 2                   false  2000-01-13 00:00:00  ...                   false
# 3                   false  2000-02-03 00:00:00  ...                   false
# 4                   false  2003-11-21 00:00:00  ...                   false
# ...                   ...                  ...  ...                     ...
# 23182               False  2001-03-23 00:00:00  ...                   False
# 23183               False  2003-12-03 00:00:00  ...                   False
# 23184               False  2000-10-08 00:00:00  ...                   False
# 23185               False  2004-02-29 00:00:00  ...                   False
# 23186               False  2005-04-06 00:00:00  ...                   False
#
#                       41                     42  \
# 0      snomed_concept_id  snomed_description_id
# 1              163020007              254063019
# 2              167273002              259803019
# 3              286647002              426047013
# 4              248333004              370729019
# ...                  ...                    ...
# 23182          370202007             1208954011
# 23183          163020007              254063019
# 23184          170656008              264567012
# 23185    997531000000108       2572661000000117
# 23186   1010601000000105       2564971000000119
#
#                                          43  \
# 0              emis_parent_observation_guid
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 23182                                   NaN
# 23183                                   NaN
# 23184                                   NaN
# 23185                                   NaN
# 23186  265A7273-2863-4AAF-BDF7-881DD528BAB2
#
#                                          44      45        46             47  \
# 0               exa_parent_observation_guid     uom  uom_ucum  user_selected
# 1                                       NaN     NaN       NaN            NaN
# 2                                       NaN     NaN       NaN            NaN
# 3                                       NaN     NaN       NaN            NaN
# 4                                       NaN      cm        cm            NaN
# ...                                     ...     ...       ...            ...
# 23182                                   NaN     NaN       NaN            NaN
# 23183                                   NaN     NaN       NaN            NaN
# 23184                                   NaN     NaN       NaN            NaN
# 23185                                   NaN     NaN       NaN            NaN
# 23186  2455013f-7c79-5b3d-90f9-03fec5de7d9c  mmol/L    mmol/L            NaN
#
#                  48          49
# 0      numericvalue  value_pq_2
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4           150.000         NaN
# ...             ...         ...
# 23182           NaN         NaN
# 23183           NaN         NaN
# 23184           NaN         NaN
# 23185           NaN         NaN
# 23186           1.1         NaN
#
# [23187 rows x 50 columns]

# %%
# Concatenating all observation csvs into one table

observation0 = observation0.iloc[1:] # column names are first row
observation0
observation0 = observation0.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation1 = observation1.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation2 = observation2.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation3 = observation3.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation4 = observation4.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation5 = observation5.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation6 = observation6.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation7 = observation7.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation8 = observation8.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation9 = observation9.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation10 = observation10.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)
observation11 = observation11.set_axis(["abnormal","emis_code_id","comparator","confidential_flag","confidential_patient_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","document_guid","dummy_patient_flag","effective_date","effective_date_precision","emis_enteredby_userinrole_guid","emis_episodicity","end_date","fhir_episodicity","emis_observation_guid","exa_observation_guid","fhir_interpretation_code","is_parent_flag","non_regular_and_current_active_flag","emis_observation_id","observation_type","emis_observationtypeid","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","other_code","other_code_system","other_display","range_lower","range_upper","readv2_code","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","emis_parent_observation_guid","exa_parent_observation_guid","uom","uom_ucum","user_selected","numericvalue","value_pq_2"], axis = 1)

observation_list = [observation0, observation1, observation2, observation3, observation4, observation5, observation6, observation7, observation8, observation9, observation10, observation11]

observation_table = pd.concat(observation_list)

# observation_table

# %%
# Concatenating all medication csvs into one table

medication0 = medication0.iloc[1:] # column names are first row
# medication0
medication0 = medication0.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication1 = medication1.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication2 = medication2.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication3 = medication3.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication4 = medication4.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication5 = medication5.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication6 = medication6.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication7 = medication7.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication8 = medication8.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication9 = medication9.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication10 = medication10.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication11 = medication11.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication12 = medication12.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication13 = medication13.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)
medication14 = medication14.set_axis(["nhs_prescribing_agency","emis_drug_guid","authorisedissues_authorised_date","authorisedissues_first_issue_date","cancellation_reason","emis_code_id","confidential_flag","consultation_source_emis_code_id","consultation_source_emis_original_term","dose","emis_medication_status","dummy_patient_flag","duration_in_days","duration_uom","effective_date","effective_date_precision","emis_issue_method","emis_mostrecent_issue_date","emis_prescription_type","emis_registration_organisation_guid","emis_encounter_guid","exa_encounter_guid","end_date","emis_enteredby_userinrole_guid","exa_prescription_guid","estimated_nhs_cost","exa_drug_guid","medication_guid","exa_medication_guid","fhir_medication_intent","exa_mostrecent_issue_date","max_nextissue_days","min_nextissue_days","non_regular_and_current_active_flag","number_authorised","number_of_issues","opt_out_93c1_flag","opt_out_9nd19nu09nu4_flag","opt_out_9nd19nu0_flag","opt_out_9nu0_flag","emis_medication_organisation_guid","other_code","other_code_system","prescribed_as_contraceptive_flag","privately_prescribed_flag","quantity","recorded_date","registration_guid","regular_and_current_active_flag","regular_current_active_and_inactive_flag","regular_patient_flag","reimburse_type","review_date","emis_original_term","sensitive_flag","sensitive_patient_flag","snomed_concept_id","snomed_description_id","fhir_medication_status","cancellation_date","nhs_prescription_type","uom","uom_dmd"], axis = 1)

medication_list = [medication0,medication1,medication2,medication3,medication4,medication5,medication6,medication7,medication8,medication9,medication10,medication11,medication12,medication13,medication14]

medication_table = pd.concat(medication_list)

medication_table
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17036\2859640830.py:23: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   medication_table = pd.concat(medication_list)
#           nhs_prescribing_agency                        emis_drug_guid  \
# 1      prescribed-at-gp-practice                                   NaN
# 2      prescribed-at-gp-practice                                   NaN
# 3      prescribed-at-gp-practice                                   NaN
# 4      prescribed-at-gp-practice                                   NaN
# 5      prescribed-at-gp-practice                                   NaN
# ...                          ...                                   ...
# 15058  prescribed-at-gp-practice  23DC3B2A-8984-4EDA-98B9-CFB9D2ECF361
# 15059  prescribed-at-gp-practice  AD382A01-3034-4EC9-9494-285CE5239AF1
# 15060  prescribed-at-gp-practice  9A4F1F64-F209-40BC-B529-C803E85821C4
# 15061  prescribed-at-gp-practice  97C9D388-B65D-4CD5-9B3F-0BAB037F14D2
# 15062  prescribed-at-gp-practice  234C68C2-00C9-4CF2-A301-7120D39214D1
#
#       authorisedissues_authorised_date authorisedissues_first_issue_date  \
# 1                  2005-04-13 00:00:00               2005-04-13 00:00:00
# 2                  2007-08-15 00:00:00               2007-08-15 00:00:00
# 3                  2005-05-10 00:00:00               2005-05-10 00:00:00
# 4                  2008-03-13 00:00:00               2008-03-13 00:00:00
# 5                  2008-06-14 00:00:00               2008-06-14 00:00:00
# ...                                ...                               ...
# 15058                              NaN                               NaN
# 15059                              NaN                               NaN
# 15060                              NaN                               NaN
# 15061                              NaN                               NaN
# 15062                              NaN                               NaN
#
#       cancellation_reason      emis_code_id confidential_flag  \
# 1                     NaN   266241000033110             false
# 2                     NaN  3943341000033113             false
# 3                     NaN  2215141000033110             false
# 4                     NaN   849641000033117             false
# 5                     NaN  1467541000033114             false
# ...                   ...               ...               ...
# 15058                 NaN   838041000033116             False
# 15059                 NaN  1418941000033115             False
# 15060                 NaN    91141000033119             False
# 15061                 NaN  1563241000033113             False
# 15062                 NaN  3196841000033116             False
#
#        consultation_source_emis_code_id  \
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# ...                                 ...
# 15058                               NaN
# 15059                               NaN
# 15060                               NaN
# 15061                               NaN
# 15062                               NaN
#
#       consultation_source_emis_original_term               dose  ...  \
# 1                                        NaN  APPLY TWICE A DAY  ...
# 2                                        NaN         2 PUFFS BD  ...
# 3                                        NaN          5 MLS QDS  ...
# 4                                        NaN           5 MLS OD  ...
# 5                                        NaN          10 MLS BD  ...
# ...                                      ...                ...  ...
# 15058                                    NaN     TAKE ONE DAILY  ...
# 15059                                    NaN        AS DIRECTED  ...
# 15060                                    NaN                 OD  ...
# 15061                                    NaN          ONE NIGHT  ...
# 15062                                    NaN        AS DIRECTED  ...
#
#                                       emis_original_term sensitive_flag  \
# 1                                  Clotrimazole 1% cream          false
# 2      Clenil Modulite 100micrograms/dose inhaler (Ch...          false
# 3       Paracetamol 250mg/5ml oral suspension sugar free          false
# 4                       Loratadine 5mg/5ml oral solution          false
# 5       Trimethoprim 50mg/5ml oral suspension sugar free          false
# ...                                                  ...            ...
# 15058                         Lisinopril  Tablets  20 mg          False
# 15059  Tetanus Immunoglobulin  Injection  250 iu/ml p...          False
# 15060                           Atenolol  Tablets  50 mg          False
# 15061                         Zopiclone  Tablets  7.5 mg          False
# 15062  Fortisip Bottle  Liquid Feed (Mixed Flavours) ...          False
#
#       sensitive_patient_flag   snomed_concept_id snomed_description_id  \
# 1                      false           326203005    107737701000001118
# 2                      false   10618211000001109     52438301000001111
# 3                      false   39024611000001102      1615391000001112
# 4                      false   38896711000001106      1574471000001116
# 5                      false   39022311000001100      1614851000001112
# ...                      ...                 ...                   ...
# 15058                  False         318860005.0   56974901000001120.0
# 15059                  False  9478811000001102.0   30981401000001116.0
# 15060                  False         318420003.0   56911901000001112.0
# 15061                  False         321175006.0   56913501000001120.0
# 15062                  False                 NaN                   NaN
#
#       fhir_medication_status cancellation_date nhs_prescription_type  \
# 1                  completed               NaN                 acute
# 2                     active               NaN                repeat
# 3                  completed               NaN                 acute
# 4                  completed               NaN                 acute
# 5                  completed               NaN                 acute
# ...                      ...               ...                   ...
# 15058              completed               NaN                repeat
# 15059              completed               NaN                 acute
# 15060              completed               NaN                repeat
# 15061              completed               NaN                repeat
# 15062              completed               NaN                repeat
#
#                       uom uom_dmd
# 1                 gram(s)     NaN
# 2                 inhaler     NaN
# 3                      ml     NaN
# 4                      ml     NaN
# 5                      ml     NaN
# ...                   ...     ...
# 15058           tablet(s)     NaN
# 15059  pre-filled syrg(s)     NaN
# 15060              tablet     NaN
# 15061           tablet(s)     NaN
# 15062           bottle(s)     NaN
#
# [214016 rows x 63 columns]

# %%
psql.sqldf("""SELECT * FROM observation_table""")
# Out:
#        abnormal     emis_code_id comparator confidential_flag  \
# 0         false        253669010       None             false
# 1         false  173141000006118       None             false
# 2         false  137851000000113       None             false
# 3         false  619931000006119       None             false
# 4         false        102928018       None             false
# ...         ...              ...        ...               ...
# 275760        0  144821000006115       None                 0
# 275761        0        397211016       None                 0
# 275762        0   11561000000115       None                 0
# 275763        1       1488841016       None                 0
# 275764        1       1488841016       None                 0
#
#        confidential_patient_flag consultation_source_emis_code_id  \
# 0                          false                 1672871000006114
# 1                          false                 1672871000006114
# 2                          false                 1672871000006114
# 3                          false                             None
# 4                          false                             None
# ...                          ...                              ...
# 275760                         0                             None
# 275761                         0                             None
# 275762                         0             1.67287100000611e+15
# 275763                         0             1.67287100000611e+15
# 275764                         0             1.67287100000611e+15
#
#        consultation_source_emis_original_term document_guid  \
# 0                                Main Surgery          None
# 1                                Main Surgery          None
# 2                                Main Surgery          None
# 3                                        None          None
# 4                                        None          None
# ...                                       ...           ...
# 275760                                   None          None
# 275761                                   None          None
# 275762                           Main Surgery          None
# 275763               General Practice Surgery          None
# 275764               General Practice Surgery          None
#
#        dummy_patient_flag       effective_date  ... sensitive_patient_flag  \
# 0                   false  2003-11-21 00:00:00  ...                  false
# 1                   false  2004-12-30 00:00:00  ...                  false
# 2                   false  2003-09-17 00:00:00  ...                  false
# 3                   false  2006-08-20 00:00:00  ...                  false
# 4                   false  2006-10-22 00:00:00  ...                  false
# ...                   ...                  ...  ...                    ...
# 275760                  0  2003-02-22 00:00:00  ...                      0
# 275761                  0  2021-11-15 00:00:00  ...                      0
# 275762                  0  2001-09-29 00:00:00  ...                      0
# 275763                  0  2001-03-27 00:00:00  ...                      0
# 275764                  0  2005-01-14 00:00:00  ...                      0
#
#        snomed_concept_id snomed_description_id  \
# 0              248333004             370729019
# 1              182918009       173141000006118
# 2         88551000000109       137851000000113
# 3       1091811000000102      2734671000000117
# 4       1022651000000100      2553501000000111
# ...                  ...                   ...
# 275760  1000651000000109      2573011000000117
# 275761           3457005        18841000006116
# 275762     1331000000103      1596371000000114
# 275763  1014641000000102      2579001000000116
# 275764  1014641000000102      2579001000000116
#
#                 emis_parent_observation_guid  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3       C1286EE9-FC69-9394-51E7-F14729E08CF1
# 4                                       None
# ...                                      ...
# 275760  E27A80E6-064F-4C9B-BF5C-C2E0956F345E
# 275761                                  None
# 275762                                  None
# 275763                                  None
# 275764                                  None
#
#                  exa_parent_observation_guid      uom uom_ucum user_selected  \
# 0                                       None       cm       cm          None
# 1                                       None     None     None          None
# 2                                       None     None     None          None
# 3       d20a59e5-dab5-581c-aea2-04d5d8a61b34    mm Hg     None          None
# 4                                       None  x10^9/L     None          None
# ...                                      ...      ...      ...           ...
# 275760  7e8d2932-9150-5b7f-8016-933f86a340c4   mmol/L   mmol/L          None
# 275761                                  None     None     None          None
# 275762                                  None     None     None          None
# 275763                                  None     None     None          None
# 275764                                  None     None     None          None
#
#        numericvalue value_pq_2
# 0           150.000       None
# 1              None       None
# 2              None       None
# 3            77.000       None
# 4           636.000       None
# ...             ...        ...
# 275760          4.5       None
# 275761         None       None
# 275762         None       None
# 275763         None       None
# 275764         None       None
#
# [275765 rows x 50 columns]

# %%
patient
# Out:
#       age  postcode patient_surname patient_givenname        date_of_birth  \
# 0       0   HX2 8WG            Bibi           Maureen  2023-02-11 00:00:00
# 1       0  LS10 8MH         O'Brien             Karen  2022-11-08 00:00:00
# 2       0  WF17 2XU          Turner              Mark  2023-01-28 00:00:00
# 3       0  WF13 3RJ             Law         Frederick  2022-12-05 00:00:00
# 4       0  LS99 9ZZ          Connor           Emerald  2022-11-17 00:00:00
# ...   ...       ...             ...               ...                  ...
# 4538    0  LS99 9ZZ           Lyons             Ahmir  2023-01-08 00:00:00
# 4539    0  LS99 9ZZ      Williamson             Cyrus  2023-02-09 00:00:00
# 4540    0  LS99 9ZZ           Healy            Kamari  2022-12-10 00:00:00
# 4541    0  LS99 9ZZ          Bolton         Zachariah  2022-11-23 00:00:00
# 4542    0  LS99 9ZZ         Johnson          Adrianna  2022-12-05 00:00:00
#
#      date_of_death                     registration_guid  patient_id  \
# 0              NaN  9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457
# 1              NaN  57E3019C-25E6-4591-AA6D-3139AF37DC3F       11488
# 2              NaN  A1700F02-134E-42FF-B537-1B7DA00F8C25        9844
# 3              NaN  CEDE39B9-9261-4B21-9E07-92D4308E87D5        9972
# 4              NaN  9532DEBE-42CC-40E4-820A-55DF603E0D23       18955
# ...            ...                                   ...         ...
# 4538           NaN  61CE65F5-271B-4151-8700-70DE00CC0A9B       29589
# 4539           NaN  4C16CFF4-520C-4B1C-8B03-9B214BDFAC76       19592
# 4540           NaN  21107E5F-CE16-4669-9B6E-43671212E9D0       27505
# 4541           NaN  9F8F0E53-7252-4998-A035-6809941C8A83       30629
# 4542           NaN  F2E5C6F8-52B3-477B-83B2-955A9BB227A5       26947
#
#              gender
# 0            Female
# 1            Female
# 2              Male
# 3              Male
# 4     Indeterminate
# ...             ...
# 4538         Female
# 4539         Female
# 4540  Indeterminate
# 4541           Male
# 4542         Female
#
# [4543 rows x 9 columns]

# %%
# Solution 1

psql.sqldf("""
           SELECT SUBSTR(postcode,1,2) AS 'Area',
           COUNT(case when gender = 'Male' then 1 end) AS 'Male',
           COUNT(case when gender = 'Female' then 1 end) AS 'Female',
           COUNT(case when gender = 'Indeterminate' then 1 end) AS 'Indeterminate',
           COUNT(case when gender = 'Unknown' then 1 end) AS 'Unknown',
           COUNT(*) AS 'Total'
           FROM patient
           GROUP BY Area
           ORDER BY Total DESC""")
# psql.sqldf("""
# SELECT gender,COUNT(gender) AS 'Count' FROM patient
# GROUP BY gender """)
# Out:
#     Area  Male  Female  Indeterminate  Unknown  Total
# 0     LS   873     902            435      430   2640
# 1     WF   289     281              0        0    570
# 2     BD   258     265              0        0    523
# 3     HX   142     131              0        0    273
# 4     HD   120      97              0        0    217
# 5   None    57      41              4        3    105
# 6     S7    30      25              0        0     55
# 7     OL    15      23              0        0     38
# 8     BS    11      14              1        0     26
# 9     SE     8       8              0        0     16
# 10    N1     5       3              0        0      8
# 11    WR     4       2              1        0      7
# 12    TF     4       0              0        0      4
# 13    SN     3       1              0        0      4
# 14    HP     1       3              0        0      4
# 15    W2     0       3              0        0      3
# 16    SW     1       2              0        0      3
# 17    S3     1       2              0        0      3
# 18    EC     1       2              0        0      3
# 19    CF     3       0              0        0      3
# 20    W3     1       1              0        0      2
# 21    SO     2       0              0        0      2
# 22    NR     0       2              0        0      2
# 23    NE     1       1              0        0      2
# 24    AY     1       1              0        0      2
# 25    YO     1       0              0        0      1
# 26    XX     1       0              0        0      1
# 27    W1     0       1              0        0      1
# 28    UB     0       1              0        0      1
# 29    SA     1       0              0        0      1
# 30    S2     0       1              0        0      1
# 31    S1     1       0              0        0      1
# 32    OX     1       0              0        0      1
# 33    OH     1       0              0        0      1
# 34    NT     0       0              1        0      1
# 35    NP     1       0              0        0      1
# 36    NB     1       0              0        0      1
# 37    N2     0       1              0        0      1
# 38    MK     0       1              0        0      1
# 39    M6     1       0              0        0      1
# 40    LL     0       1              0        0      1
# 41    LA     0       1              0        0      1
# 42    G4     0       1              0        0      1
# 43    G2     0       1              0        0      1
# 44    EX     0       1              0        0      1
# 45    EH     0       0              0        1      1
# 46    E1     0       1              0        0      1
# 47    DE     0       1              0        0      1
# 48    BN     0       1              0        0      1
# 49    BB     1       0              0        0      1
# 50    BA     0       1              0        0      1
# 51    B1     0       1              0        0      1
# 52    AN     1       0              0        0      1

# %%
psql.sqldf("""
           SELECT p.registration_guid, p.patient_id, p.patient_surname, p.patient_givenname, p.postcode, p.age, p.gender
           FROM patient p
           INNER JOIN medication_table m ON (m.registration_guid=p.registration_guid)
           """)
# Out:
#                            registration_guid  patient_id patient_surname  \
# 0       9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457            Bibi
# 1       9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457            Bibi
# 2       9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457            Bibi
# 3       9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457            Bibi
# 4       9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457            Bibi
# ...                                      ...         ...             ...
# 214011  6D3A2201-4791-419D-A025-A6D62DF28136       11368       Schofield
# 214012  6D3A2201-4791-419D-A025-A6D62DF28136       11368       Schofield
# 214013  6D3A2201-4791-419D-A025-A6D62DF28136       11368       Schofield
# 214014  40679503-39DB-4BA9-B927-E508448B371D       12413          Savage
# 214015  40679503-39DB-4BA9-B927-E508448B371D       12413          Savage
#
#        patient_givenname  postcode  age  gender
# 0                Maureen   HX2 8WG    0  Female
# 1                Maureen   HX2 8WG    0  Female
# 2                Maureen   HX2 8WG    0  Female
# 3                Maureen   HX2 8WG    0  Female
# 4                Maureen   HX2 8WG    0  Female
# ...                  ...       ...  ...     ...
# 214011              Neil  LS28 3VF    0    Male
# 214012              Neil  LS28 3VF    0    Male
# 214013              Neil  LS28 3VF    0    Male
# 214014            Claire  WF10 6GL    0  Female
# 214015            Claire  WF10 6GL    0  Female
#
# [214016 rows x 7 columns]

# %%
patient
# Out:
#       age  postcode patient_surname patient_givenname        date_of_birth  \
# 0       0   HX2 8WG            Bibi           Maureen  2023-02-11 00:00:00
# 1       0  LS10 8MH         O'Brien             Karen  2022-11-08 00:00:00
# 2       0  WF17 2XU          Turner              Mark  2023-01-28 00:00:00
# 3       0  WF13 3RJ             Law         Frederick  2022-12-05 00:00:00
# 4       0  LS99 9ZZ          Connor           Emerald  2022-11-17 00:00:00
# ...   ...       ...             ...               ...                  ...
# 4538    0  LS99 9ZZ           Lyons             Ahmir  2023-01-08 00:00:00
# 4539    0  LS99 9ZZ      Williamson             Cyrus  2023-02-09 00:00:00
# 4540    0  LS99 9ZZ           Healy            Kamari  2022-12-10 00:00:00
# 4541    0  LS99 9ZZ          Bolton         Zachariah  2022-11-23 00:00:00
# 4542    0  LS99 9ZZ         Johnson          Adrianna  2022-12-05 00:00:00
#
#      date_of_death                     registration_guid  patient_id  \
# 0              NaN  9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457
# 1              NaN  57E3019C-25E6-4591-AA6D-3139AF37DC3F       11488
# 2              NaN  A1700F02-134E-42FF-B537-1B7DA00F8C25        9844
# 3              NaN  CEDE39B9-9261-4B21-9E07-92D4308E87D5        9972
# 4              NaN  9532DEBE-42CC-40E4-820A-55DF603E0D23       18955
# ...            ...                                   ...         ...
# 4538           NaN  61CE65F5-271B-4151-8700-70DE00CC0A9B       29589
# 4539           NaN  4C16CFF4-520C-4B1C-8B03-9B214BDFAC76       19592
# 4540           NaN  21107E5F-CE16-4669-9B6E-43671212E9D0       27505
# 4541           NaN  9F8F0E53-7252-4998-A035-6809941C8A83       30629
# 4542           NaN  F2E5C6F8-52B3-477B-83B2-955A9BB227A5       26947
#
#              gender
# 0            Female
# 1            Female
# 2              Male
# 3              Male
# 4     Indeterminate
# ...             ...
# 4538         Female
# 4539         Female
# 4540  Indeterminate
# 4541           Male
# 4542         Female
#
# [4543 rows x 9 columns]

# %%
clinical_codes
# Out:
#      refset_simple_id  parent_code_id            code_id  snomed_concept_id  \
# 0        9.990129e+17             NaN   9315231000006113       1.067599e+16
# 1        9.990129e+17             NaN          301451010       1.959490e+08
# 2        9.990116e+17             NaN   7627141000006111       7.080300e+08
# 3        9.990129e+17             NaN  13844351000006118       7.039540e+08
# 4        9.990116e+17             NaN          506053014       8.440900e+07
# ..                ...             ...                ...                ...
# 581      9.990116e+17             NaN          139979010       8.440900e+07
# 582      9.990116e+17             NaN   3921361000006112       8.743300e+07
# 583               NaN    1.223821e+15   9299341000033119                NaN
# 584               NaN    7.173210e+14   3164141000033119                NaN
# 585               NaN    5.912210e+14   9995641000033112                NaN
#
#                                              emis_term
# 0    Acute severe exacerbation of mild persistent a...
# 1                            Chronic wheezy bronchitis
# 2    Pulmonary emphysema co-occurrent with fibrosis...
# 3    Asthma caused by house dust mite, Dermatophago...
# 4                          Purulent chronic bronchitis
# ..                                                 ...
# 581                           Fetid chronic bronchitis
# 582                                  Emphysema of lung
# 583  Olodaterol 2.5micrograms/dose solution for inh...
# 584  Fluticasone propionate 250micrograms/dose / Sa...
# 585  Aclidinium bromide 396micrograms/dose / Formot...
#
# [586 rows x 5 columns]

# %%
medication_table
# Out:
#           nhs_prescribing_agency                        emis_drug_guid  \
# 4      prescribed-at-gp-practice                                   NaN
# 5      prescribed-at-gp-practice                                   NaN
# 6      prescribed-at-gp-practice                                   NaN
# 7      prescribed-at-gp-practice                                   NaN
# 8      prescribed-at-gp-practice                                   NaN
# ...                          ...                                   ...
# 15058  prescribed-at-gp-practice  23DC3B2A-8984-4EDA-98B9-CFB9D2ECF361
# 15059  prescribed-at-gp-practice  AD382A01-3034-4EC9-9494-285CE5239AF1
# 15060  prescribed-at-gp-practice  9A4F1F64-F209-40BC-B529-C803E85821C4
# 15061  prescribed-at-gp-practice  97C9D388-B65D-4CD5-9B3F-0BAB037F14D2
# 15062  prescribed-at-gp-practice  234C68C2-00C9-4CF2-A301-7120D39214D1
#
#       authorisedissues_authorised_date authorisedissues_first_issue_date  \
# 4                  2008-03-13 00:00:00               2008-03-13 00:00:00
# 5                  2008-06-14 00:00:00               2008-06-14 00:00:00
# 6                  2008-06-05 00:00:00               2008-06-05 00:00:00
# 7                  2007-08-15 00:00:00               2007-08-15 00:00:00
# 8                  2005-05-10 00:00:00               2005-05-10 00:00:00
# ...                                ...                               ...
# 15058                              NaN                               NaN
# 15059                              NaN                               NaN
# 15060                              NaN                               NaN
# 15061                              NaN                               NaN
# 15062                              NaN                               NaN
#
#       cancellation_reason      emis_code_id confidential_flag  \
# 4                     NaN   849641000033117             false
# 5                     NaN  1467541000033114             false
# 6                     NaN  1467541000033114             false
# 7                     NaN  2804441000033110             false
# 8                     NaN  1739441000033117             false
# ...                   ...               ...               ...
# 15058                 NaN   838041000033116             False
# 15059                 NaN  1418941000033115             False
# 15060                 NaN    91141000033119             False
# 15061                 NaN  1563241000033113             False
# 15062                 NaN  3196841000033116             False
#
#        consultation_source_emis_code_id  \
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# ...                                 ...
# 15058                               NaN
# 15059                               NaN
# 15060                               NaN
# 15061                               NaN
# 15062                               NaN
#
#       consultation_source_emis_original_term            dose  ...  \
# 4                                        NaN        5 MLS OD  ...
# 5                                        NaN       10 MLS BD  ...
# 6                                        NaN         10ML BD  ...
# 7                                        NaN     AS DIRECTED  ...
# 8                                        NaN       5 MLS QDS  ...
# ...                                      ...             ...  ...
# 15058                                    NaN  TAKE ONE DAILY  ...
# 15059                                    NaN     AS DIRECTED  ...
# 15060                                    NaN              OD  ...
# 15061                                    NaN       ONE NIGHT  ...
# 15062                                    NaN     AS DIRECTED  ...
#
#                                       emis_original_term sensitive_flag  \
# 4                       Loratadine 5mg/5ml oral solution          false
# 5       Trimethoprim 50mg/5ml oral suspension sugar free          false
# 6       Trimethoprim 50mg/5ml oral suspension sugar free          false
# 7              AeroChamber Plus (Trudell Medical UK Ltd)          false
# 8         Ibuprofen 100mg/5ml oral suspension sugar free          false
# ...                                                  ...            ...
# 15058                         Lisinopril  Tablets  20 mg          False
# 15059  Tetanus Immunoglobulin  Injection  250 iu/ml p...          False
# 15060                           Atenolol  Tablets  50 mg          False
# 15061                         Zopiclone  Tablets  7.5 mg          False
# 15062  Fortisip Bottle  Liquid Feed (Mixed Flavours) ...          False
#
#       sensitive_patient_flag   snomed_concept_id snomed_description_id  \
# 4                      false   38896711000001106      1574471000001116
# 5                      false   39022311000001100      1614851000001112
# 6                      false   39022311000001100      1614851000001112
# 7                      false    9516911000001109    106215701000001110
# 8                      false   39108111000001104      1674861000001115
# ...                      ...                 ...                   ...
# 15058                  False         318860005.0   56974901000001120.0
# 15059                  False  9478811000001102.0   30981401000001116.0
# 15060                  False         318420003.0   56911901000001112.0
# 15061                  False         321175006.0   56913501000001120.0
# 15062                  False                 NaN                   NaN
#
#       fhir_medication_status cancellation_date nhs_prescription_type  \
# 4                  completed               NaN                 acute
# 5                  completed               NaN                 acute
# 6                  completed               NaN                 acute
# 7                  completed               NaN                 acute
# 8                  completed               NaN                 acute
# ...                      ...               ...                   ...
# 15058              completed               NaN                repeat
# 15059              completed               NaN                 acute
# 15060              completed               NaN                repeat
# 15061              completed               NaN                repeat
# 15062              completed               NaN                repeat
#
#                       uom uom_dmd
# 4                      ml     NaN
# 5                      ml     NaN
# 6                      ml     NaN
# 7                  device     NaN
# 8                      ml     NaN
# ...                   ...     ...
# 15058           tablet(s)     NaN
# 15059  pre-filled syrg(s)     NaN
# 15060              tablet     NaN
# 15061           tablet(s)     NaN
# 15062           bottle(s)     NaN
#
# [214013 rows x 63 columns]

# %%
# Solution 2
psql.sqldf("""
           SELECT postcode,
           COUNT(case when gender = 'Male' then 1 end) AS 'Male',
           COUNT(case when gender = 'Female' then 1 end) AS 'Female',
           COUNT(case when gender = 'Indeterminate' then 1 end) AS 'Indeterminate',
           COUNT(case when gender = 'Unknown' then 1 end) AS 'Unknown',
           COUNT(*) AS 'Total'
           FROM patient
           GROUP BY postcode
           ORDER BY Total DESC""")
# Out:
#       age  postcode patient_surname patient_givenname        date_of_birth  \
# 0       0   HX2 8WG            Bibi           Maureen  2023-02-11 00:00:00
# 1       0  LS10 8MH         O'Brien             Karen  2022-11-08 00:00:00
# 2       0  WF17 2XU          Turner              Mark  2023-01-28 00:00:00
# 3       0  WF13 3RJ             Law         Frederick  2022-12-05 00:00:00
# 4       0  LS99 9ZZ          Connor           Emerald  2022-11-17 00:00:00
# ...   ...       ...             ...               ...                  ...
# 4538    0  LS99 9ZZ           Lyons             Ahmir  2023-01-08 00:00:00
# 4539    0  LS99 9ZZ      Williamson             Cyrus  2023-02-09 00:00:00
# 4540    0  LS99 9ZZ           Healy            Kamari  2022-12-10 00:00:00
# 4541    0  LS99 9ZZ          Bolton         Zachariah  2022-11-23 00:00:00
# 4542    0  LS99 9ZZ         Johnson          Adrianna  2022-12-05 00:00:00
#
#      date_of_death                     registration_guid  patient_id  \
# 0              NaN  9A70C9CD-D0F7-43F3-A05C-34C8F192E00C       10457
# 1              NaN  57E3019C-25E6-4591-AA6D-3139AF37DC3F       11488
# 2              NaN  A1700F02-134E-42FF-B537-1B7DA00F8C25        9844
# 3              NaN  CEDE39B9-9261-4B21-9E07-92D4308E87D5        9972
# 4              NaN  9532DEBE-42CC-40E4-820A-55DF603E0D23       18955
# ...            ...                                   ...         ...
# 4538           NaN  61CE65F5-271B-4151-8700-70DE00CC0A9B       29589
# 4539           NaN  4C16CFF4-520C-4B1C-8B03-9B214BDFAC76       19592
# 4540           NaN  21107E5F-CE16-4669-9B6E-43671212E9D0       27505
# 4541           NaN  9F8F0E53-7252-4998-A035-6809941C8A83       30629
# 4542           NaN  F2E5C6F8-52B3-477B-83B2-955A9BB227A5       26947
#
#              gender
# 0            Female
# 1            Female
# 2              Male
# 3              Male
# 4     Indeterminate
# ...             ...
# 4538         Female
# 4539         Female
# 4540  Indeterminate
# 4541           Male
# 4542         Female
#
# [4543 rows x 9 columns]
